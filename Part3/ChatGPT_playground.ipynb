# %%
import openai
import os

# %%
with open('../sample_data/token.txt', 'r') as file:
    os.environ["OPENAI_API_KEY"] = file.read().strip()

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
client = openai.OpenAI()

# %% [markdown]
# # ChatGPT CHAT

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": "너는 친절한 초등학생 아이다."
    },
    {
      "role": "user",
      "content": "무지개 색에 대해서 얘기해줘"
    }
  ],
  temperature=1,
  max_tokens=384,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-9s9xR6vVk6zS0CyafXeOSgep48QmH', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='물론! 무지개는 비가 내린 뒤 해가 뜰 때 볼 수 있는 아주 아름다운 자연 현상이야. 무지개는 일곱 가지 색으로 이루어져 있지. 그 색들은 빨간색, 주황색, 노란색, 초록색, 파란색, 남색, 그리고 보라색이야. 이 색들은 빛이 물방울을 통과하면서 굴절되고 반사되어 생기는 거야.\n\n기억하기 쉽게 "빨주노초파남보" 이렇게 외우기도 해! 무지개를 볼 때마다 이 일곱 색들을 찾아보는 것도 재미있을 거야. 다음에 비가 온 뒤에 해가 뜨면 하늘을 한 번 주의 깊게 살펴봐! 무지개를 볼 수도 있으니까! 🌈', role='assistant', function_call=None, tool_calls=None))], created=1722695017, model='gpt-4o-2024-05-13', object='chat.completion', service_tier=None, system_fingerprint='fp_4e2b2da518', usage=CompletionUsage(completion_tokens=181, prompt_tokens=33, total_tokens=214))

# %%
print(response.choices[0].message.content)
# Out:
# 물론! 무지개는 비가 내린 뒤 해가 뜰 때 볼 수 있는 아주 아름다운 자연 현상이야. 무지개는 일곱 가지 색으로 이루어져 있지. 그 색들은 빨간색, 주황색, 노란색, 초록색, 파란색, 남색, 그리고 보라색이야. 이 색들은 빛이 물방울을 통과하면서 굴절되고 반사되어 생기는 거야.
#
# 기억하기 쉽게 "빨주노초파남보" 이렇게 외우기도 해! 무지개를 볼 때마다 이 일곱 색들을 찾아보는 것도 재미있을 거야. 다음에 비가 온 뒤에 해가 뜨면 하늘을 한 번 주의 깊게 살펴봐! 무지개를 볼 수도 있으니까! 🌈

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI()

# %%
text = '웃긴 얘기 해 줘'

# %%
print(llm.invoke(text).content)
# Out:
# 왜 초등학생들이 수영을 배우면서 항상 손을 먼저 내밀까요?
#
# 그 이유는 물 속에 들어갈 때 손을 먼저 내밀어서 "안녕하세요~" 라고 인사하기 때문이라고 해요!

# %% [markdown]
# # ChatGPT Whisper API

# %%
from IPython.display import Audio, display, HTML

# %%
display(Audio("../sample_data/Sample_voice.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_file= open("../sample_data/Sample_voice.mp3", "rb")

transcription = client.audio.transcriptions.create(
  model="whisper-1",
  file=audio_file
)
print("Done")
# Out:
# Done

# %%
print(transcription.text)
# Out:
# 안녕하세요. 제 이름은 민우입니다.

# %%
translation = client.audio.translations.create(
  model="whisper-1",
  file=audio_file
)
print("Done")
# Out:
# Done

# %%
print(translation.text)
# Out:
# Hello, my name is Minwoo.

# %% [markdown]
# # ChatGPT TTS

# %%
speech_file_path = '../sample_data/tts_sample.mp3'

# %%
response = client.audio.speech.create(
  model='tts-1',
  voice='alloy',
  input='안녕하세요 제 이름은 미누입니다'
)

response.stream_to_file(speech_file_path)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_40744\3886900263.py:7: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file_path)

# %%
display(Audio(speech_file_path))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # ChatGPT Vision

# %% [markdown]
# <img src="https://geographical.co.uk/wp-content/uploads/shutterstock_1853507206-1.jpg" width="700">

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "이거 설명해"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://geographical.co.uk/wp-content/uploads/shutterstock_1853507206-1.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %%
print(response.choices[0].message.content)
# Out:
# 이 이미지는 심해 탐사를 주제로 한 그림입니다. 위쪽에는 해양 탐사선이 바다 표면에 떠 있는 모습이 보입니다. 탐사선에서 해저 깊숙이 잠수정이나 원격 조정 장비가 내려가고 있는 모습입니다.
#
# 아래쪽에는 해저 협곡이 펼쳐져 있으며, 깊고 어두운 바다 속으로 들어가는 잠수정을 볼 수 있습니다. 이 협곡은 매우 깊으며, 물고기나 기타 해양 생물들도 심해에서 탐사를 도와주는 장비 근처에 있는 모습이 보입니다.
#
# 이 그림은 심해 탐사 활동, 즉 인간이 접근하기 어려운 깊은 해저 지역을 탐사하는 과정을 시각화한 것입니다. 해저 탐사를 통해 해양 생태계, 지질 구조, 자연 자원 및 기타과학적 정보를 연구하고 탐사할 수 있습니다.

# %%
import base64
import requests

# %%
def encode_image(image_path):
  with open(image_path, 'rb') as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# %%
image_path = '../sample_data/sample_image.jpg'

# %% [markdown]
# <img src="../sample_data/sample_image.jpg" width="300">

# %%
base64_image = encode_image(image_path)

# %%
api_key = openai.api_key

# %%
headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

# %%
payload = {
  "model": "gpt-4o",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "설명해줘!"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

# %%
response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

# %%
print(response.json()['choices'][0]['message']['content'])
# Out:
# 이 이미지에는 한 사람이 활을 당기면서 양궁을 준비하는 모습이 담겨 있습니다. 이 사람은 활을 항상 겨냥하고 있고, 손목과 팔에 보호대나 가능성이 있는 장비를 착용하고 있습니다. 그의 허리에는 화살통이 매달려 있으며, 여러 개의 화살이 살짝 보입니다. 이 사람은 흰색 셔츠와 검은색 바지를 입고 있으며, 흰색 운동화를 신고 있습니다. 또한, 셔츠의 오른쪽 어깨 부근에 있는 로고와 문자로 보아 양궁 클럽 소속임을 알 수 있습니다.
#
# 이미지는 녹색 잔디밭 위에서 촬영되었으며, 뒤에 있는 나무들과 전봇대를 통해 야외에서 진행되는 활동임을 확인할 수 있습니다. 이미지의 왼쪽 하단에는 23번 표지판이 배치되어 있어 특정 자리나 타겟을 나타내는 것으로 보입니다.

# %% [markdown]
# # chatGPT Image generation

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt='양궁하는 뒷모습',
  size="1024x1024",
  quality="standard",
  n=1
)

# %%
image_url = response.data[0].url

# %%
html = f'<img src="{image_url}" width="500">' # You can adjust the width as needed
display(HTML(html))
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-3dLGyNo2drtK8OFr98MlslQu/user-ifj05VMN30iTkmzBR13LPPOe/img-UW5bfNeiZqZosESn61nbXSyQ.png?st=2024-08-03T13%3A26%3A00Z&se=2024-08-03T15%3A26%3A00Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-03T05%3A35%3A32Z&ske=2024-08-04T05%3A35%3A32Z&sks=b&skv=2023-11-03&sig=qaUui/g/thX6trQJbG/WxJtR1X1hG6KG8Bt4IfMCkdE%3D" width="500">
