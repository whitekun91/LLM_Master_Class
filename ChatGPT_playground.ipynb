# %%
import openai
import os

# %%
with open('./sample_data/token.txt', 'r') as file:
    os.environ["OPENAI_API_KEY"] = file.read().strip()

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
client = openai.OpenAI()

# %% [markdown]
# # ChatGPT CHAT

# %%
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": "너는 친절한 초등학생 아이다."
    },
    {
      "role": "user",
      "content": "무지개 색에 대해서 얘기해줘"
    }
  ],
  temperature=1,
  max_tokens=384,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-9ijfqZH25VevJ6x48orkPwXyAfTXp', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='안녕! 무지개는 빛이 물방울이나 비 등에서 반사되어 만들어지는 자연의 아름다운 현상이야. 무지개의 색깔은 일곱 가지로 나뉘어져 있는데, 빨강, 주황, 노랑, 초록, 파랑, 남색, 보라색이야.\n\n무지개에서 이렇게 다양한 색깔이 나타나는 이유는 빛의 스펙트럼이 다양한 파장을 가지기 때문이야. 빛이 공기나 물방울 등의 매질을 통과하거나 반사되면 빛의 파장이 분산되어 다양한 색깔로 나타나는거야. 이러한 현상을 빛의 굴절이라고 해!\n\n무지개는 맑은 하늘에 나타나는 경우가 많은데, 비가 내리고 태양이 나타나면 무지개의 아름다운 색깔을 구경할 수 있어. 무지개는 자연의 아름다움을 느낄 수 있는 특별한 현상이니까, 항상 주위를 살펴보며 무지개를 발견하면 기분이 좋아질 거야! 함', role='assistant', function_call=None, tool_calls=None))], created=1720449030, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=383, prompt_tokens=45, total_tokens=428))

# %%
print(response.choices[0].message.content)
# Out:
# 안녕! 무지개는 빛이 물방울이나 비 등에서 반사되어 만들어지는 자연의 아름다운 현상이야. 무지개의 색깔은 일곱 가지로 나뉘어져 있는데, 빨강, 주황, 노랑, 초록, 파랑, 남색, 보라색이야.
#
# 무지개에서 이렇게 다양한 색깔이 나타나는 이유는 빛의 스펙트럼이 다양한 파장을 가지기 때문이야. 빛이 공기나 물방울 등의 매질을 통과하거나 반사되면 빛의 파장이 분산되어 다양한 색깔로 나타나는거야. 이러한 현상을 빛의 굴절이라고 해!
#
# 무지개는 맑은 하늘에 나타나는 경우가 많은데, 비가 내리고 태양이 나타나면 무지개의 아름다운 색깔을 구경할 수 있어. 무지개는 자연의 아름다움을 느낄 수 있는 특별한 현상이니까, 항상 주위를 살펴보며 무지개를 발견하면 기분이 좋아질 거야! 함

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI()

# %%
text = '웃긴 얘기 해 줘'

# %%
print(llm.invoke(text).content)
# Out:
# 왜 초등학생이 책을 읽을 때 항상 옆에서 눈치를 보냈을까요?
#
# 그 이유는 책이 눈치를 본다고 생각했기 때문이에요! 😄

# %% [markdown]
# # ChatGPT Whisper API

# %%
from IPython.display import Audio, display, HTML

# %%
display(Audio("./sample_data/Sample_voice.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_file= open("./sample_data/Sample_voice.mp3", "rb")

transcription = client.audio.transcriptions.create(
  model="whisper-1",
  file=audio_file
)
print("Done")
# Out:
# Done

# %%
print(transcription.text)
# Out:
# 안녕하세요. 제 이름은 민우입니다.

# %%
translation = client.audio.translations.create(
  model="whisper-1",
  file=audio_file
)
print("Done")
# Out:
# Done

# %%
print(translation.text)
# Out:
# Hello, my name is Minwoo.

# %% [markdown]
# # ChatGPT TTS

# %%
speech_file_path = './sample_data/tts_sample.mp3'

# %%
response = client.audio.speech.create(
  model='tts-1',
  voice='alloy',
  input='안녕하세요 제 이름은 미누입니다'
)

response.stream_to_file(speech_file_path)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_39728\3886900263.py:7: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file_path)

# %%
display(Audio(speech_file_path))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # ChatGPT Vision

# %% [markdown]
# <img src="https://geographical.co.uk/wp-content/uploads/shutterstock_1853507206-1.jpg" width="700">

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "이거 설명해"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://geographical.co.uk/wp-content/uploads/shutterstock_1853507206-1.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %%
print(response.choices[0].message.content)
# Out:
# 이 이미지는 해양 탐사를 나타내고 있습니다. 이미지 상단에는 배가 물 표면 위에 떠 있습니다. 이 배는 해저 탐사를 수행하기 위한 탐사선으로 보입니다. 배에서 아래로 긴 케이블이 내려져 있으며, 그 끝에는 해저를 탐사하는 잠수정이나 원격 조정 잠수기(ROV)가 연결된 것처럼 보입니다.
#
# 이미지의 중간 부분부터 하단 부분은 깊은 해구를 나타내고 있습니다. 해구는 지구의 해저에서 가장 깊은 지형 중 하나로, 산맥이 양쪽으로 솟아 있는 모습이 보입니다. 해구 속에는 몇몇 더 작은 잠수정이나 장비들이 배치되어 있거나 탐사를 수행 중인 모습이 묘사되어 있습니다.
#
# 이 그림은 해양 생태계 연구, 지질 연구, 또는 해저 자원 탐사를 나타내는 예시로 사용될 수 있습니다. 해양 탐사는 지구의 미지의 영역을 이해하고, 해양 생물들을 연구하며, 해저 자원을 탐사하는 데 중요한 역할을 합니다.

# %%
import base64
import requests

# %%
def encode_image(image_path):
  with open(image_path, 'rb') as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# %%
image_path = './sample_data/sample_image.jpg'

# %% [markdown]
# <img src="./sample_data/sample_image.jpg" width="300">

# %%
base64_image = encode_image(image_path)

# %%
api_key = openai.api_key

# %%
headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

# %%
payload = {
  "model": "gpt-4o",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "설명해줘!"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

# %%
response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

# %%
print(response.json()['choices'][0]['message']['content'])
# Out:
# 이 사진은 양궁 연습 또는 경기 중인 장면입니다. 사진 속에 있는 사람들은 활과 화살 등의 양궁 장비를 착용하고 있으며, 표적을 겨냥하고 있습니다. 주요 특징들을 설명드리겠습니다:
#
# 1. **활**: 사진 속 인물들이 사용하는 활은 리커브 보우(Recurve Bow)로 보입니다. 리커브 보우는 올림픽 경기에서도 사용하는 활 중 하나입니다.
#
# 2. **자세**: 사진 속 인물은 활 시위를 당기고 표적을 정조준하는 자세를 취하고 있습니다. 이는 정확한 사격을 위해 필요한 기본 자세입니다.
#
# 3. **장비**: 허리 쪽에 화살을 보관하는 화살통(quiver), 팔 보호대(arm guard), 손목 보호대 등이 보입니다. 이는 사격 중 부상을 방지하기 위한 보호 장비입니다.
#
# 4. **장소**: 사진 배경을 보면 야외에서 촬영된 것으로 보이며, 양궁 경기장이나 연습장일 가능성이 큽니다.
#
# 이 장면은 정확한 사격을 위해 집중하는 양궁 선수의 모습으로, 양궁은 많은 집중력과 기술을 요구하는 스포츠입니다.

# %% [markdown]
# # chatGPT Image generation

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt='양궁하는 뒷모습',
  size="1024x1024",
  quality="standard",
  n=1
)

# %%
image_url = response.data[0].url

# %%
html = f'<img src="{image_url}" width="500">' # You can adjust the width as needed
display(HTML(html))
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-3dLGyNo2drtK8OFr98MlslQu/user-ifj05VMN30iTkmzBR13LPPOe/img-lqoj4fi1o0dnjV9SwKBzS4EI.png?st=2024-07-10T12%3A06%3A23Z&se=2024-07-10T14%3A06%3A23Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-10T02%3A18%3A16Z&ske=2024-07-11T02%3A18%3A16Z&sks=b&skv=2023-11-03&sig=2Hm6Wb9jFBxraXNfWCp%2B7PSUjs%2BMLShV56ea%2BpfuBvc%3D" width="500">
